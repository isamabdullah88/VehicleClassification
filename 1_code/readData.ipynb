# %%
import os

import cv2
import numpy as np
import matplotlib.pyplot as plt
from mat4py import loadmat

# %%
mat_path = '../0_data/devkit/cars_train_annos.mat'
meta_path = '../0_data/devkit/cars_meta.mat'

meta = loadmat(meta_path)
data = loadmat(mat_path)

# %%
# print(data['annotations']['class'])
# print(data['annotations']['fname'])
class_names = meta['class_names']
labels = [l-1 for l in data['annotations']['class']]
imgs = data['annotations']['fname']

# %%
idx = 0
img_path = '../0_data/cars_train/'+imgs[idx]
img = cv2.imread(img_path)
plt.imshow(img)
plt.title(class_names[labels[idx]])
# Out:
# Text(0.5, 1.0, 'Audi TTS Coupe 2012')
