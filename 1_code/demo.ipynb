# %% [markdown]
# ## Demo notebook for testing trained models.
# - This notebook shows how to test and evaluate deep learning models for the problem of Vehicle Classification from images. There are total of 196 classes, and about 8000 training images.

# %% [markdown]
# #### Import required packages

# %%
import os
import cv2
import matplotlib.pyplot as plt

from testModel import TestModel
from data import get_imgpath_labels

from config import *
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Read model and prepare test class
# - Please make sure that the annotation file for test set has same format as that of dataset. It is absolutely crucial.

# %%
model_path = '../2_outputs/trainedModels/model.02-0.65.hdf5'
test_matfile = 'devkit/cars_test_annos.mat'

# We are only testing, not training. We don't have labels for testing set
img_names_list, _ = get_imgpath_labels(test_matfile, train=False)

testModel = TestModel(model_path)
# Out:
# WARNING:tensorflow:From d:\kagglecompetitions\pyenv\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Take each image and predict its class

# %%
# Image number to test from 8000 images
img_idx = 1900

img_path = os.path.join(DATA_DIR, IMG_DIR, img_names_list[img_idx])

pred_class, conf_class, class_name = testModel.get_preds(img_path)

# %% [markdown]
# ### Display the image with class name

# %%
plt.figure(figsize=(12,8))
plt.imshow(cv2.imread(img_path))
plt.title('Class: {0:s}  |  Confidence: {1:.02f}'.format(class_name, conf_class), fontsize=15)
plt.show()
